# %%
import pandas as pd

mapa = pd.read_csv('./UFO_modify1.csv')

# %%
mapa['end_time'] = ''

# %%
mapa.columns
# Out:
# Index(['Unnamed: 0', 'datetime', 'city', 'state', 'country', 'shape',
#        'duration (seconds)', 'comments', 'date posted', 'latitude',
#        'longitude', 'date', 'end_time'],
#       dtype='object')

# %%
fluorish = pd.DataFrame(mapa, columns= ['latitude', 'longitude', 'date', 'end_time', 'shape', 'duration (seconds)'])

# %%
display(fluorish)
# Out:
#         latitude   longitude        date end_time      shape  \
# 0      29.883056  -97.941111  1949-10-10            cylinder
# 1      29.384210  -98.581082  1949-10-10               light
# 2      53.200000   -2.916667  1955-10-10              circle
# 3      28.978333  -96.645833  1956-10-10              circle
# 4      21.418056 -157.803611  1960-10-10               light
# 5      36.595000  -82.188889  1961-10-10              sphere
# 6      51.434722   -3.180000  1965-10-10              circle
# 7      41.117500  -73.408333  1965-10-10                disk
# 8      33.586111  -86.286111  1966-10-10                disk
# 9      30.294722  -82.984167  1966-10-10                disk
# 10     33.916389 -118.351667  1968-10-10              circle
# 11     35.233333  -82.734444  1968-10-10            fireball
# 12     40.668611  -73.527500  1970-10-10                disk
# 13     37.153611  -83.761944  1970-10-10             unknown
# ...

# %%
fluorish['shape'].unique()
# Out:
# array(['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball',
#        'unknown', 'oval', 'other', 'cigar', 'rectangle', 'chevron',
#        'triangle', 'formation', nan, 'delta', 'changing', 'egg', 'flash',
#        'diamond', 'cross', 'teardrop', 'cone', 'us', 'au', 'ur (iceland)',
#        'ca', 'al', 'pyramid', 'round', 'ma', 'mb', 'nv', 'crescent',
#        'flare', 'ga', 'hexagon', 'dome', 'gb', 'il', 'mt', 'changed',
#        '  (taiwan)', 'mn'], dtype=object)

# %%
fluorish.to_csv("fluorish_UFO.csv")
