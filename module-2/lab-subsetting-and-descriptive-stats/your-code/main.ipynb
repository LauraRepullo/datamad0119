# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import matplotlib
# %matplotlib inline
import scipy
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
df_temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
df_temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
df_temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
df_temp[df_temp.State == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
df_temp[df_temp.State == 'New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

len(df_temp[df_temp.Temperature < 15])
# Out:
# 3

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here

df_temp.City[df_temp.Temperature < 15]
# Out:
# 1        Albany
# 2       Buffalo
# 4    Bridgeport
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
df_temp[df_temp.Temperature > 15][df_temp.Temperature < 20]['City']
# Out:
# /home/laura/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here

mean_NY = df_temp[df_temp.State == 'New York'].mean()
std_NY = df_temp[df_temp.State == 'New York'].std()

mean_ Conn = df_temp[df_temp.State == 'Connecticut'].mean()
std_ Conn = df_temp[df_temp.State == 'Connecticut'].std()

mean_ NJ = df_temp[df_temp.State == 'New Jersey'].mean()
std _ NJ = df_temp[df_temp.State == 'New Jersey'].std()
# Out:
# Temperature    1.571348
# dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()

#Salary: la mayor parte de los empleados del dataset cobran entre 10-35
#Years:la mayoria delos empleados lleva entre 1,5 y 3 años.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa1b5555828>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee.Salary == 30]['Name']
#df_temp[df_temp.Temperature > 15][df_temp.Temperature < 20]['City']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name == "David"]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[employee.Salary > 55][employee.Title == "associate"]['Name']
# Out:
# /home/laura/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 7    Pedro
# Name: Name, dtype: object

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby(['Years'])['Salary'].mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby(['Title'])['Salary'].mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.describe()

#Years: 1er percentil: 2.00, y 3º: 7.00
#Salary: 1er percentil: 35.00, y 3º: 60.00
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %%
# print third quartile here

#Years: 7.00
#Salary: 60.00

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby(['Gender'])['Salary'].mean()

#Yes, is different: male's is higher than female´s.
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.zip')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
Purchase_Price = orders.Quantity.mean()*orders.UnitPrice.mean()
# Out:
# 40.57827334161581

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['purchase_price']= orders.Quantity * orders.UnitPrice
highest_purchase_price = orders.purchase_price.max()
highest_purchase_price
# Out:
# 168469.6

# %%
# your answer here
lowest_purchase_price = orders.purchase_price.min()
lowest_purchase_price
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
customers_spain = orders[orders.Country == "Spain"][["CustomerID"]]
customers_spain.head()
# Out:
#       CustomerID
# 4250       12557
# 4251       12557
# 4252       12557
# 4253       12557
# 4254       12557

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders['CustomerID'].value_counts("Country" == 'Spain')
# Out:
# 17841    7847
# 14911    5677
# 14096    5111
# 12748    4596
# 14606    2700
# 15311    2379
# 14646    2080
# 13089    1818
# 13263    1677
# 14298    1637
# 15039    1502
# 14156    1400
# 18118    1279
# 14159    1204
# 14796    1141
# 16033    1137
# 15005    1119
# 14056    1106
# 14769    1090
# 13081    1028
# 16549     981
# 14527     972
# 14456     970
# 17511     963
# 15719     937
# 15555     899
# 16931     898
# 17811     851
# 14505     799
# 18283     756
#          ...
# 16073       1
# 14351       1
# 16881       1
# 14424       1
# 18084       1
# 18133       1
# 17752       1
# 13017       1
# 17102       1
# 18174       1
# 17443       1
# 17763       1
# 13270       1
# 15070       1
# 15389       1
# 13099       1
# 15510       1
# 13391       1
# 13135       1
# 16742       1
# 17956       1
# 15562       1
# 17923       1
# 17715       1
# 15195       1
# 17331       1
# 16093       1
# 13703       1
# 13307       1
# 12346       1
# ...

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders.Quantity > 50][['CustomerID']].head()
# Out:
#      CustomerID
# 46        13748
# 83        15291
# 96        14688
# 102       14688
# 174       16029

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[orders.Quantity > 50][orders.Country == 'Spain'].head()
# Out:
# /home/laura/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
# 4253        6424     536944     20725  2010     12    5    12
# 4254        6425     536944     20728  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot        70  2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue       100  2010-12-03 12:20:00       1.45
#
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders = orders[orders.UnitPrice == 0]
free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here:
lunch_bag_orders = orders[orders["Description"].str.contains ('lunch bag')]
lunch_bag_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# 361            370     536401     20726  2010     12    3    11
# 362            371     536401     22384  2010     12    3    11
# 402            411     536404     22383  2010     12    3    11
# 403            412     536404     20728  2010     12    3    11
# 404            413     536404     20727  2010     12    3    11
# 532            541     536412     20728  2010     12    3    11
# 533            542     536412     22382  2010     12    3    11
# 535            544     536412     22662  2010     12    3    11
# 536            545     536412     22383  2010     12    3    11
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
lunch_bag_orders_2011 = orders[[orders.year == 2011][orders.Description].str.contains ('lunch bag')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-a91c4b14146c> in <module>
#       1 # your answer here
# ----> 2 lunch_bag_orders_2011 = orders[[orders.year == 2011][orders.Description].str.contains ('lunch bag')]
#
# TypeError: list indices must be integers or slices, not Series

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
freq_distr_Spain = orders.amount_spent[orders.Country == 'Spain'].hist()

freq_distr_Spain

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders_August = orders[orders.month == 8]
orders_August
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
countries_August = orders[orders.month == 8]['Country'].value_counts()
countries_August
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
Average_money_per_country = orders.groupby(orders['Country'])[['amount_spent']].agg('mean').head()
Average_money_per_country
# Out:
#            amount_spent
# Country
# Australia    116.895620
# Austria       25.624824
# Bahrain       32.258824
# Belgium       20.283772
# Brazil        35.737500

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

most_expensive_item = orders[orders.UnitPrice == orders.UnitPrice.max()]['Description']
most_expensive_item
# Out:
# 118352    postage
# Name: Description, dtype: object

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
Average_money_per_year = orders.groupby(orders['year'])[['amount_spent']].agg('mean')
Average_money_per_year
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
