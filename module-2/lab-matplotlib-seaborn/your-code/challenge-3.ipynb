# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
numerical_variable = titanic.select_dtypes(exclude='object').columns.tolist()
numerical_variable
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
#your code here- categorical variable
categorical_variable = titanic.select_dtypes(include='object').columns.tolist()
categorical_variable
# Out:
# ['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib.style
import matplotlib as mpl

plt.style.use('classic')
plt.rcParams['figure.figsize'] = ('12.0','6.0')

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
f,(ax1, ax2, ax3) = plt.subplots(1, 3)
num_bins1 = 10
num_bins2 = 20
num_bins3 = 50 
# the histogram of the data
plt.subplot(131)
ax1 = plt.hist(titanic['Age'], num_bins1, normed=1, facecolor='g', alpha=0.5)
plt.subplot(132)
ax2 = plt.hist(titanic['Age'], num_bins2, normed=1, facecolor='b', alpha=0.5)
plt.subplot(133)
ax3 = plt.hist(titanic['Age'], num_bins3, normed=1, facecolor='r', alpha=0.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#cuantos mas bins, mas dificil es analizar la información

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
plt.pie(titanic['Gender'].value_counts(), labels = ['Male', 'Female'], colors = ['b', 'pink'], shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f45b19b55f8>,
#   <matplotlib.patches.Wedge at 0x7f45b8b6ed30>],
#  [Text(-0.48083677220945115, 0.9893411941747885, 'Male'),
#   Text(0.48083667958064136, -0.9893412391939718, 'Female')])

# %%
# your code here- 2nd way
sns.countplot(x="Gender", data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic['Pclass'].hist()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f45b04ebf28>,
#   <matplotlib.lines.Line2D at 0x7f45b04e32e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f45b04e3630>,
#   <matplotlib.lines.Line2D at 0x7f45b04e3978>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f45b04ebdd8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f45b04e3cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f45b04d3048>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#el percentil 25 esta en torno a 23, el 75 en torno a 38, y la media 30. EL valor minimo es 1 y el maximo 60.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#la mayor parte de los pasajeros del Titanic tenia entre 21 y 23 años.
La edad minima era 0 y la maxima 80 años.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

#plt.scatter(x, y, s=area, c=colors, alpha=0.5)
#plt.show()

plt.scatter(titanic['Age'], titanic['Fare'])
plt.show()

# %%
# your code-2nd way
sns.scatterplot(titanic['Age'], titanic['Fare'])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
pd.plotting.scatter_matrix(titanic)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0b45208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0add748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0a84cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0a35278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0a5b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0a02d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc09b3320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc09da8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc09da908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc09333c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc095a940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0901eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc08b1470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc08d79e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0881f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0b27ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0ba79e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0b64358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0c14860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0bc5128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0b786a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc083cc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc07ef1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0816748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc07bccc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0770278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc07967f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc073ed68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc06f0320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0717898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc06c0e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc06703c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0698940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0643eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc05f5470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc06199e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc05c3f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0573518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc059aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc054f048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc04f65c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc051cb38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc04cf0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0474668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc049ebe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0451198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc03f7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc0421c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc03d1240>]],
#       dtype=object)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
Pclass y Fare
Age y SibSp

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
sns.boxplot(x='Gender',y='Age',data=titanic)
