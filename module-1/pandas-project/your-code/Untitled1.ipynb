# %%
import pandas as pd
pd.read_csv('SharkAttacks_ordered_by_year.csv')
# Out:
#       Year                      Date            Time            Country  \
# 0     2016                 14-Jun-16           17h30                USA
# 1     2016                 24-Jan-16   09h30 / 10h00                USA
# 2     2016                 05-Sep-16  Late afternoon                USA
# 3     2016                 15-Jul-16             NaN                USA
# 4     2016                 27-Jun-16           16h20                USA
# 5     2016                 21-Jun-16           15h25                USA
# 6     2016                 07-Jun-16           11h30                USA
# 7     2016                 25-Jun-16           14h34                USA
# 8     2016                 11-Jun-16           15h00                USA
# 9     2016                 07-Jul-16           10h00                USA
# 10    2016                 07-Sep-16           14h30                USA
# 11    2016                 06-Aug-16             NaN                USA
# ...
